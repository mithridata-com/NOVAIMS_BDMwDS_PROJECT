# %% [markdown]
# # ATTACHING MAIN PACKAGES

# %%
import os
import pandas as pd
import sys
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")       # optional aesthetics
# %matplotlib inline

# %% [markdown]
# # READING THE DATA

# %%
data_path = r"C:\Users\dimet\Documents\GitHub\NOVAIMS_BDMwDS_PROJECT\00 Data"

# %%
# Function to load each Excel file into its own DataFrame
def load_excel_dataframe(filename: str, sheet_name: str) -> pd.DataFrame:
    """
    Load a sheet from an Excel file into a pandas DataFrame.
    Prints the shape on success or an error message on failure.
    """
    file_path = os.path.join(data_path, filename)
    try:
        df = pd.read_excel(file_path, sheet_name=sheet_name)
        print(f"Loaded '{sheet_name}' from '{filename}' (shape: {df.shape})")
        return df
    except Exception as e:
        print(f"Error loading '{sheet_name}' from '{filename}': {e}")
        return pd.DataFrame()

# %%
# Load DataFrames
df = load_excel_dataframe("Funnel.xlsx", "funnel_data")
# Out:
# Loaded 'funnel_data' from 'Funnel.xlsx' (shape: (9373, 18))

# %% [markdown]
# # 1. Quick first look

# %%
print("Shape:", df.shape)
# Out:
# Shape: (9373, 18)

# %%
display(df.head())
# Out:
#   affinity_name           status_report  offer_number  policy_number  \
# 0        Insuro        Requestwithdrawn          1000        10000.0
# 1         other  Tailoredofferwithdrawn          1001            NaN
# 2         other       Incompleterequest          1002            NaN
# 3         other           Policycreated          1003        10002.0
# 4         other           Policycreated          1004        10003.0
#
#    zipcode_link  zip4 birth_date       brand date_offer date_request  \
# 0         10000  2132 1985-01-01     HYUNDAI 2018-10-11   2018-10-11
# 1         10001  6027 1987-04-01        AUDI 2018-10-11          NaT
# 2         10002  3824 1972-11-01  VOLKSWAGEN 2018-10-11          NaT
# 3         10003  6921 1983-08-01       MAZDA 2018-10-11   2018-10-11
# 4         10004  8266 1990-04-01       VOLVO 2018-10-12   2018-10-12
#
#   policy_start_date  premium  buildyear_car buildmonth_car   wa wa_bep_ca  \
# 0        2018-11-01   686.04         2016.0           June    Y       NaN
# 1               NaT     0.00         2015.0           June    N         N
# 2               NaT   896.04         2016.0          April  NaN       NaN
# 3        2018-10-12   419.16         2009.0           June  NaN         Y
# 4        2018-11-01   402.36         2003.0        January    Y       NaN
#
#   wa_ca updated_on
# 0   NaN 2018-10-11
# 1     N 2018-10-12
# 2     Y 2018-10-11
# 3   NaN 2018-10-11
# 4   NaN 2018-10-12

# %%
display(df.tail())
# Out:
#      affinity_name           status_report  offer_number  policy_number  \
# 9368         other         Requestaccepted          9439        11946.0
# 9369         other         Waitforapproval          9440        11947.0
# 9370        Insuro  Tailoredofferrequested          9441            NaN
# 9371           T&B     Calculatenewpremium          9442            NaN
# 9372           T&B       Incompleterequest          9443            NaN
#
#       zipcode_link  zip4 birth_date       brand date_offer date_request  \
# 9368         15568  1161 1960-09-01  VOLKSWAGEN 2020-03-08   2020-03-08
# 9369         15582  5015 1953-04-01      NISSAN 2020-03-08   2020-03-08
# 9370         10332  3078 1976-04-01      TOYOTA 2020-03-08          NaT
# 9371         12968  1965 1951-07-01      TOYOTA 2020-03-08          NaT
# 9372         15526  1165 1964-01-01       VOLVO 2020-03-08          NaT
#
#      policy_start_date  premium  buildyear_car buildmonth_car   wa wa_bep_ca  \
# 9368        2020-03-09   510.68         2011.0       December  NaN       NaN
# 9369        2020-04-29   459.60         2017.0       February  NaN       NaN
# 9370               NaT   521.16         2004.0        January  NaN         Y
# 9371               NaT   368.40         2004.0      September  NaN         Y
# 9372               NaT   764.52         2015.0           June  NaN       NaN
#
#      wa_ca updated_on
# 9368     Y 2020-03-08
# 9369     Y 2020-03-08
# 9370   NaN 2020-03-08
# 9371   NaN 2020-03-08
# 9372     Y 2020-03-08

# %% [markdown]
# # 2. Metadata & basic hygiene

# %%
# 2‑a) Data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9373 entries, 0 to 9372
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   affinity_name      9373 non-null   object
#  1   status_report      9371 non-null   object
#  2   offer_number       9373 non-null   int64
#  3   policy_number      2572 non-null   float64
#  4   zipcode_link       9373 non-null   int64
#  5   zip4               9373 non-null   int64
#  6   birth_date         9230 non-null   datetime64[ns]
#  7   brand              9370 non-null   object
#  8   date_offer         9373 non-null   datetime64[ns]
#  9   date_request       2572 non-null   datetime64[ns]
#  10  policy_start_date  2676 non-null   datetime64[ns]
#  11  premium            8994 non-null   float64
#  12  buildyear_car      9370 non-null   float64
#  13  buildmonth_car     9370 non-null   object
#  14  wa                 3581 non-null   object
#  15  wa_bep_ca          3061 non-null   object
#  16  wa_ca              4091 non-null   object
#  17  updated_on         9373 non-null   datetime64[ns]
# dtypes: datetime64[ns](5), float64(3), int64(3), object(7)
# memory usage: 1.3+ MB

# %%
# 2‑b) Missing‑value profile
missings = df.isna().sum().sort_values(ascending=False)
display(missings[missings > 0])
# Out:
# date_request         6801
# policy_number        6801
# policy_start_date    6697
# wa_bep_ca            6312
# wa                   5792
# wa_ca                5282
# premium               379
# birth_date            143
# buildyear_car           3
# brand                   3
# buildmonth_car          3
# status_report           2
# dtype: int64

# %%
# 2‑c) Duplicate rows
dup_count = df.duplicated().sum()
print(f"Duplicate rows: {dup_count}")
# Out:
# Duplicate rows: 0

# %% [markdown]
# # 3. Summary statistics

# %%
# 3‑a) Numeric variables
display(df.describe().T)
# Out:
#                     count                           mean                  min  \
# offer_number       9373.0                    5391.820015               1000.0
# policy_number      2572.0                   11110.490669              10000.0
# zipcode_link       9373.0                   12684.995412              10000.0
# zip4               9373.0                    4497.965753               1011.0
# birth_date           9230  1974-09-21 20:21:34.907908992  1919-01-01 00:00:00
# date_offer           9373  2019-09-13 21:05:09.954123520  2018-10-11 00:00:00
# date_request         2572  2019-09-05 13:42:27.433903616  2018-10-11 00:00:00
# policy_start_date    2676  2019-09-04 16:02:41.434977280  1920-06-03 00:00:00
# premium            8994.0                     559.225405                  0.0
# buildyear_car      9370.0                    2008.603095               1979.0
# updated_on           9373  2019-09-14 20:09:23.832284416  2018-10-11 00:00:00
#
#                                    25%                  50%  \
# offer_number                    3301.0               5566.0
# policy_number                 10643.75              11235.5
# zipcode_link                   11267.0              12664.0
# zip4                            2645.0               3824.0
# birth_date         1961-08-01 00:00:00  1976-02-01 00:00:00
# date_offer         2019-06-24 00:00:00  2019-10-21 00:00:00
# date_request       2019-06-13 00:00:00  2019-10-21 00:00:00
# policy_start_date  2019-06-21 00:00:00  2019-11-01 00:00:00
# premium                         326.16               485.22
# buildyear_car                   2004.0               2009.0
# updated_on         2019-06-25 00:00:00  2019-10-22 00:00:00
#
#                                    75%                  max          std
# offer_number                    7487.0               9443.0  2420.194235
# policy_number                 11580.25              11947.0   554.914133
# zipcode_link                   14076.0              15582.0  1609.273189
# zip4                            6712.0               9991.0  2391.129168
# birth_date         1990-07-01 00:00:00  2002-01-01 00:00:00          NaN
# date_offer         2019-12-19 00:00:00  2020-03-08 00:00:00          NaN
# date_request       2019-12-19 00:00:00  2020-03-08 00:00:00          NaN
# policy_start_date  2020-01-01 00:00:00  2021-02-04 00:00:00          NaN
# premium                         697.65              3780.72   380.807301
# buildyear_car                   2014.0               2020.0     6.008221
# updated_on         2019-12-20 00:00:00  2020-03-08 00:00:00          NaN

# %%
# 3‑b) Categorical variables (top‑10 value counts each)
cat_cols = df.select_dtypes(include=["object", "category"]).columns
for c in cat_cols:
    print(f"\n--- {c} ---")
    display(df[c].value_counts(dropna=False).head(10))
# Out:
# --- affinity_name ---
# affinity_name
# T&B                           3715
# other                         2627
# Seguros International Ltd.    1615
# Insuro                        1416
# Name: count, dtype: int64
# --- status_report ---
# status_report
# Calculatenewpremium       2881
# Incompleterequest         2732
# Policycreated             1694
# Personaloffer              707
# Waitresponsebackoffice     386
# Tailoredofferrequested     206
# Tailoredofferrejected      191
# Waitforapproval            167
# Requestaccepted            127
# Requestrejected            102
# Name: count, dtype: int64
# --- brand ---
# brand
# VOLKSWAGEN    1090
# OPEL           770
# PEUGEOT        764
# RENAULT        663
# FORD           627
# TOYOTA         605
# BMW            451
# VOLVO          390
# CITROEN        384
# FIAT           333
# Name: count, dtype: int64
# --- buildmonth_car ---
# buildmonth_car
# January      1142
# March         996
# June          847
# September     808
# May           783
# October       780
# November      741
# February      737
# July          707
# April         703
# Name: count, dtype: int64
# --- wa ---
# wa
# NaN    5792
# Y      2854
# N       727
# Name: count, dtype: int64
# --- wa_bep_ca ---
# wa_bep_ca
# NaN    6312
# Y      2352
# N       709
# Name: count, dtype: int64
# --- wa_ca ---
# wa_ca
# NaN    5282
# Y      3376
# N       715
# Name: count, dtype: int64

# %% [markdown]
# # 4. Target variable & funnel conversion checks

# %%
premium_rate = df['premium'].mean()
print(f"Premium rate: {premium_rate:0.5}")
# Out:
# Premium rate: 559.23

# %% [markdown]
# # 5. Univariate distributions

# %%
num_cols = df.select_dtypes(include=np.number).columns
for col in num_cols:
    plt.figure(figsize=(4,2))
    sns.histplot(df[col].dropna(), kde=True)
    plt.title(col)
    plt.show()

# %% [markdown]
# # 6. Bivariate relationships

# %%
# 6‑a) Correlation heat‑map for numerics
plt.figure(figsize=(10,8))
corr = df[num_cols].corr()
sns.heatmap(corr, annot=False, cmap="coolwarm", vmax=1, vmin=-1)
plt.title("Pearson correlations")
plt.show()

# %% [markdown]
# # 7. Categorical vs. target

# %%
pd.pivot_table(
    df, values=["premium"],
    index=["affinity_name"],
    columns=["brand"],
    aggfunc="mean",
)
# Out:
#                                 premium                                   \
# brand                        ALFA ROMEO APRILIA ASTON MARTIN        AUDI
# affinity_name
# Insuro                      1115.242500   98.46          NaN  697.770000
# Seguros International Ltd.   459.440000     NaN          NaN  554.200000
# T&B                          592.350000     NaN      1872.44  870.459048
# other                        813.030769     NaN          NaN  938.477273
#
#                                                                         \
# brand                      BENTLEY         BMW BUELL BUICK   CHEVROLET
# affinity_name
# Insuro                         NaN  490.545490   NaN   NaN  433.680000
# Seguros International Ltd.     NaN  611.428085   NaN   NaN  394.026667
# T&B                            0.0  646.577482   NaN   0.0  513.372000
# other                          NaN  795.996902   0.0   NaN  565.843636
#
#                                           ...                             \
# brand                      CHEVROLET USA  ...   SUBARU      SUZUKI   SYM
# affinity_name                             ...
# Insuro                               NaN  ...  547.780  380.448421  87.0
# Seguros International Ltd.       1041.42  ...  259.920  356.763797   NaN
# T&B                                  NaN  ...  632.796  466.394158   NaN
# other                             448.00  ...  336.440  388.006364   NaN
#
#                                                                              \
# brand                         TESLA      TOYOTA TRIUMPH   VESPA  VOLKSWAGEN
# affinity_name
# Insuro                      1527.12  516.543226  359.28  197.82  561.354171
# Seguros International Ltd.  1370.40  432.634902   98.16     NaN  462.733764
# T&B                          786.00  488.140095     NaN     NaN  707.356362
# other                        964.38  560.322468   40.38     NaN  737.402696
#
#
# brand                            VOLVO     YAMAHA
# affinity_name
# Insuro                      773.584390  65.331429
# Seguros International Ltd.  449.905000        NaN
# T&B                         592.014766   0.000000
# other                       760.124383  99.792308
#
# [4 rows x 63 columns]

# %%
pd.pivot_table(
    df, values=["premium"],
    index=["affinity_name"],
    columns=["status_report"],
    aggfunc="mean",
)
# Out:
#                                             premium                      \
# status_report              Adaptedproposalwithdrawn Calculatenewpremium
# affinity_name
# Insuro                                          NaN          496.639233
# Seguros International Ltd.                      NaN          440.878635
# T&B                                             NaN          572.597743
# other                                        853.72          670.875741
#
#                                                             \
# status_report              Incompleterequest Personaloffer
# affinity_name
# Insuro                            586.692792    300.318140
# Seguros International Ltd.        440.767786    336.219802
# T&B                               631.009924    492.821946
# other                             667.288810    573.185806
#
#                                                                 \
# status_report              Personalofferrejected Policycreated
# affinity_name
# Insuro                                    118.08    500.373167
# Seguros International Ltd.                875.04    424.243713
# T&B                                       506.04    648.862283
# other                                     403.26    656.207908
#
#                                                                              \
# status_report              Requestaccepted Requestrejected Requestwithdrawn
# affinity_name
# Insuro                          493.413750      672.070000       438.438824
# Seguros International Ltd.      373.115806      629.553750       656.290000
# T&B                             552.109111      790.274545       563.465600
# other                           646.638286      802.782667       596.149048
#
#                                                                          \
# status_report              Tailoredofferrejected Tailoredofferrequested
# affinity_name
# Insuro                                136.698000             341.554286
# Seguros International Ltd.            297.152727             496.092632
# T&B                                   154.346796             484.038750
# other                                 116.755789             377.074737
#
#                                                                    \
# status_report              Tailoredofferwithdrawn Waitforapproval
# affinity_name
# Insuro                                  67.520000      530.998000
# Seguros International Ltd.             712.650000      510.454000
# T&B                                    146.667368      773.889000
# other                                  168.443077      754.178846
#
#
# status_report              Waitresponsebackoffice
# affinity_name
# Insuro                                 530.478679
# Seguros International Ltd.             405.185875
# T&B                                    578.618345
# other                                  649.442105

# %%
pd.pivot_table(
    df, values=["premium"],
    index=["affinity_name"],
    columns=["status_report"],
    aggfunc="count",
)
# Out:
#                                             premium                      \
# status_report              Adaptedproposalwithdrawn Calculatenewpremium
# affinity_name
# Insuro                                          NaN               313.0
# Seguros International Ltd.                      NaN               359.0
# T&B                                             NaN              1037.0
# other                                           1.0               864.0
#
#                                                             \
# status_report              Incompleterequest Personaloffer
# affinity_name
# Insuro                                 462.0          86.0
# Seguros International Ltd.             524.0         101.0
# T&B                                   1057.0         334.0
# other                                  689.0         186.0
#
#                                                                 \
# status_report              Personalofferrejected Policycreated
# affinity_name
# Insuro                                       1.0         360.0
# Seguros International Ltd.                   1.0         404.0
# T&B                                          5.0         495.0
# other                                        4.0         435.0
#
#                                                                              \
# status_report              Requestaccepted Requestrejected Requestwithdrawn
# affinity_name
# Insuro                                16.0            12.0             17.0
# Seguros International Ltd.            31.0            16.0             13.0
# T&B                                   45.0            44.0             25.0
# other                                 35.0            30.0             21.0
#
#                                                                          \
# status_report              Tailoredofferrejected Tailoredofferrequested
# affinity_name
# Insuro                                      20.0                   14.0
# Seguros International Ltd.                  11.0                   19.0
# T&B                                        103.0                   64.0
# other                                       57.0                   38.0
#
#                                                                    \
# status_report              Tailoredofferwithdrawn Waitforapproval
# affinity_name
# Insuro                                        3.0            20.0
# Seguros International Ltd.                    4.0            45.0
# T&B                                          57.0            50.0
# other                                        26.0            52.0
#
#
# status_report              Waitresponsebackoffice
# affinity_name
# Insuro                                       53.0
# Seguros International Ltd.                   80.0
# T&B                                         139.0
# other                                       114.0

# %%
df["status_report"].value_counts()
# Out:
# status_report
# Calculatenewpremium         2881
# Incompleterequest           2732
# Policycreated               1694
# Personaloffer                707
# Waitresponsebackoffice       386
# Tailoredofferrequested       206
# Tailoredofferrejected        191
# Waitforapproval              167
# Requestaccepted              127
# Requestrejected              102
# Tailoredofferwithdrawn        90
# Requestwithdrawn              76
# Personalofferrejected         11
# Adaptedproposalwithdrawn       1
# Name: count, dtype: int64
