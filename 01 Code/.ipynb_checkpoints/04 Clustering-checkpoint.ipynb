# %% [markdown]
# # 0. Attaching libraries

# %%
import os
import sqlite3
import pandas as pd
import sys
#from ydata_profiling import ProfileReport # for profiling
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
sns.set_style("whitegrid")       # optional aesthetics
# %matplotlib inline

# %%
# Pre-processing & modelling
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.cluster import KMeans

# Cluster diagnostics
from sklearn.metrics import silhouette_score

# %%
from dateutil.relativedelta import relativedelta
import builtins

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning, module="sklearn")

import matplotlib.patches as mpatches

# %%
from sklearn.decomposition import PCA

# %% [markdown]
# # 1. Reading the core Dataset from the golden source

# %%
csv_file  = "https://raw.githubusercontent.com/mithridata-com/NOVAIMS_BDMwDS_PROJECT/refs/heads/main/00%20Data/Dataset.csv?token=GHSAT0AAAAAADEUY5L6JVUTHXQ3VCDMXQUA2CHMCAQ"

excel_path  = (r"C:\Users\dimet\Documents\GitHub\NOVAIMS_BDMwDS_PROJECT\02 Output\02 TB Conversion Analytics.xlsx")

# %%
# ── Load the CSV into a DataFrame ──────────────────────────────────────────
df = pd.read_csv(csv_file, low_memory=False)

# %%
# Quick sanity check (optional)
print(df.shape)       # prints (rows, columns)
# Out:
# (9373, 78)

# %%
df.columns
# Out:
# Index(['affinity_name', 'status_report', 'offer_number', 'policy_number',
#        'zipcode_link', 'zip4', 'birth_date', 'brand', 'date_offer',
#        'date_request', 'policy_start_date', 'premium', 'buildyear_car',
#        'buildmonth_car', 'wa', 'wa_bep_ca', 'wa_ca', 'updated_on',
#        'policy_continuation_date', 'policy_start_date_pol',
#        'policy_lastchange_date', 'premium_wa', 'premium_other',
#        'zipcode_link_pol', 'zip4_pol', 'place_residence', 'birth_date_pol',
#        'gender', 'private_commercial', 'bonus_malus_percent', 'other_cover',
#        'premium_other_incl_discount', 'worth_car', 'brand_pol',
#        'builddate_car', 'weight_car', 'mileage_car', 'power_car', 'fuel_car',
#        'chassis', 'drive', 'turbo', 'transmission', 'zip4_reg', 'PROVINCE',
#        'URB', 'INCOME', 'SOCCL_A', 'SOCCL_B1', 'SOCCL_B2', 'SOCCL_C',
#        'SOCCL_D', 'EDU_HIGH', 'EDU_MID', 'EDU_LOW', 'DINK', 'OWN_HOUSE',
#        'AVG_HOUSE', 'RENT_PRICE', 'STAGE_OF_LIFE', 'SINGLE', 'FAM',
#        'FAM_WCHILD', 'SINGLES_YOUNG', 'SINGLES_MID', 'SINGLES_OLD',
#        'FAM_CHILD_Y', 'FAM_CHILD_O', 'FAM_WCHILD_Y', 'FAM_WCHILD_MED',
#        'FAM_WCHILD_OLD', 'CIT_HOUSEHOLD', 'LOAN', 'SAVINGS', 'SHOP_ONLINE',
#        'CAR', 'conv', 'churn'],
#       dtype='object')

# %% [markdown]
# ## NEW COLUMNS

# %%
df["customer_id"] = df[["zipcode_link", "zip4", "place_residence","birth_date", "gender"]].astype(str).agg("-".join, axis=1)

# %%
df['premium_total'] = df['premium_wa'].fillna(0) + df['premium_other'].fillna(0)

# %%
df['premium_discount'] = df['premium_other'].fillna(0) - df['premium_other_incl_discount'].fillna(0)

# %%
# 1. Build boolean conditions based on == "Y"
conditions = [
    df['wa'] == 'Y',
    df['wa_bep_ca'] == 'Y',
    df['wa_ca'] == 'Y'
]

# 2. Corresponding labels
choices = ['1. Only liability insurance', '2. Liability + limited casco', '3. Liability + full casco']

# 3. Create the new column, defaulting to NaN if none of the three has "Y"
df['coverage_type'] = np.select(conditions, choices, default="")

# %%
# ── 1. External “today” reference ───────────────────────────────────────────
current_date = pd.to_datetime("2019-11-01")    # ← use any value you like
fancy_date = current_date.strftime("%B %d %Y")

# %%
# ── 2. Parse birth_date & compute age ───────────────────────────────────────
# 2-a. Ensure birth_date is a datetime column
df["birth_date"] = pd.to_datetime(df["birth_date"], errors="coerce")

# 2-b. Convert to integer years using dateutil.relativedelta for accuracy
df["age"] = df["birth_date"].apply(
    lambda bd: relativedelta(current_date, bd).years if pd.notnull(bd) else pd.NA
)
# ── 1. Ensure age is numeric ────────────────────────────────────────────────
# (errors='coerce' converts any bad strings to NaN so they drop out later)
df["age"] = pd.to_numeric(df["age"], errors="coerce")

# ── 2. Create age bands ─────────────────────────────────────────────────────
age_bins   = [0, 25, 35, 45, 55, 65, 120]               # tweak if needed
age_labels = ["<25", "25–34", "35–44", "45–54", "55–64", "65+"]

# %%
df["age_band"] = pd.cut(df["age"],
                           bins=age_bins,
                           labels=age_labels,
                           right=False)

# %%
df["urb_norm"] = (
    df["URB"]
      .astype(str)
      .str.strip()
      .str[0]                    # first letter
      .str.upper()
      .replace({"1": "1-VeryHigh", "2": "2-High", "3": "3-Mid-to-High", "4": "4-Mid", "5": "5-Mid-to-Low", "6": "6-Low","7": "7-VeryLow", "0": "Unknown", "N" : "Unknown"})
)

# %%
month_map = {
    "January":   "01",
    "February":  "02",
    "March":     "03",
    "April":     "04",
    "May":       "05",
    "June":      "06",
    "July":      "07",
    "August":    "08",
    "September": "09",
    "October":   "10",
    "November":  "11",
    "December":  "12"
}

df["buildmonth_num"] = df["buildmonth_car"].map(month_map)

# %%
# 2. Combine year + month + “01” (first of month) into a YYYY-MM-DD string and convert to datetime:
df["build_date"] = pd.to_datetime(
    df["buildyear_car"].astype(str).str[:4] + "-" + 
    df["buildmonth_num"] + "-01"
)

# Now 'build_date' holds a Timestamp for the first day of that month/year.
print(df[["buildyear_car", "buildmonth_car", "build_date"]].head())
# Out:
#    buildyear_car buildmonth_car build_date
# 0         2016.0           June 2016-06-01
# 1         2015.0           June 2015-06-01
# 2         2016.0          April 2016-04-01
# 3         2009.0           June 2009-06-01
# 4         2003.0        January 2003-01-01

# %%
# Calculate car_age
df['car_age'] = current_date.year - df['build_date'].dt.year - (
    (current_date.month < df['build_date'].dt.month) |
    ((current_date.month == df['build_date'].dt.month) & (current_date.day < df['build_date'].dt.day))
).astype(int)

# %%
# 1) Make sure `policy_start_date` is a datetime:
df['policy_start_date'] = pd.to_datetime(
    df['policy_start_date'],
    errors='coerce'
)

# %%
# Define age bins and labels
bins = [0, 3, 7, 11, 100]
labels = ['0-3', '4-7', '8-11', '12+']

# Create normalized age categories
df['car_age_norm'] = pd.cut(df['car_age'], bins=bins, labels=labels, include_lowest=True).cat.add_categories('Unknown').fillna("Unknown")

# %%
df
# Out:
#      affinity_name           status_report  offer_number  policy_number  \
# 0           Insuro        Requestwithdrawn          1000        10000.0
# 1            other  Tailoredofferwithdrawn          1001            NaN
# 2            other       Incompleterequest          1002            NaN
# 3            other           Policycreated          1003        10002.0
# 4            other           Policycreated          1004        10003.0
# ...            ...                     ...           ...            ...
# 9368         other         Requestaccepted          9439        11946.0
# 9369         other         Waitforapproval          9440        11947.0
# 9370        Insuro  Tailoredofferrequested          9441            NaN
# 9371           T&B     Calculatenewpremium          9442            NaN
# 9372           T&B       Incompleterequest          9443            NaN
#
#       zipcode_link  zip4 birth_date       brand  date_offer date_request  ...  \
# 0            10000  2132 1985-01-01     HYUNDAI  2018-10-11   2018-10-11  ...
# 1            10001  6027 1987-04-01        AUDI  2018-10-11          NaN  ...
# 2            10002  3824 1972-11-01  VOLKSWAGEN  2018-10-11          NaN  ...
# 3            10003  6921 1983-08-01       MAZDA  2018-10-11   2018-10-11  ...
# 4            10004  8266 1990-04-01       VOLVO  2018-10-12   2018-10-12  ...
# ...            ...   ...        ...         ...         ...          ...  ...
# 9368         15568  1161 1960-09-01  VOLKSWAGEN  2020-03-08   2020-03-08  ...
# 9369         15582  5015 1953-04-01      NISSAN  2020-03-08   2020-03-08  ...
# 9370         10332  3078 1976-04-01      TOYOTA  2020-03-08          NaN  ...
# 9371         12968  1965 1951-07-01      TOYOTA  2020-03-08          NaN  ...
# 9372         15526  1165 1964-01-01       VOLVO  2020-03-08          NaN  ...
#
#      premium_total  premium_discount                 coverage_type   age  \
# 0              0.0               0.0   1. Only liability insurance  34.0
# 1              0.0               0.0                                32.0
# 2              0.0               0.0     3. Liability + full casco  47.0
# 3              0.0               0.0  2. Liability + limited casco  36.0
# 4              0.0               0.0   1. Only liability insurance  29.0
# ...            ...               ...                           ...   ...
# 9368           0.0               0.0     3. Liability + full casco  59.0
# 9369           0.0               0.0     3. Liability + full casco  66.0
# 9370           0.0               0.0  2. Liability + limited casco  43.0
# 9371           0.0               0.0  2. Liability + limited casco  68.0
# 9372           0.0               0.0     3. Liability + full casco  55.0
#
#      age_band       urb_norm buildmonth_num build_date car_age car_age_norm
# 0       25–34  3-Mid-to-High             06 2016-06-01     3.0          0-3
# 1       25–34      7-VeryLow             06 2015-06-01     4.0          4-7
# 2       45–54         2-High             04 2016-04-01     3.0          0-3
# 3       35–44          4-Mid             06 2009-06-01    10.0         8-11
# 4       25–34          4-Mid             01 2003-01-01    16.0          12+
# ...       ...            ...            ...        ...     ...          ...
# 9368    55–64          6-Low             12 2011-12-01     7.0          4-7
# 9369      65+         2-High             02 2017-02-01     2.0          0-3
# 9370    35–44     1-VeryHigh             01 2004-01-01    15.0          12+
# 9371      65+          4-Mid             09 2004-09-01    15.0          12+
# 9372    55–64      7-VeryLow             06 2015-06-01     4.0          4-7
#
# [9373 rows x 89 columns]

# %%
# list of cols to convert
num_cols = ['worth_car', 'weight_car', 'mileage_car', 'power_car']

# coerce to numeric, invalid parsing becomes NaN
for c in num_cols:
    df[c] = pd.to_numeric(df[c], errors='coerce')

# %% [markdown]
# # IMPUTATION

# %%
num_cols = [
    'worth_car',
    'weight_car',
    'mileage_car',
    'power_car'
]

cat_cols = [
    'chassis',
    'fuel_car',
    'drive',
    'turbo',
    'transmission'
]

# %%
# for each numeric column, fill NAs with the mean _within_ its brand
df[num_cols] = (
    df
    .groupby('brand')[num_cols]
    .transform(lambda col:
        col.fillna(col.mean())    # group-mean imputation
    )
)

# %%
def fill_with_mode(series):
    # find the most common value
    modes = series.dropna().mode()
    if len(modes) > 0:
        return series.fillna(modes.iloc[0])
    else:
        return series

df[cat_cols] = (
    df
    .groupby('brand')[cat_cols]
    .transform(fill_with_mode)
)

# %%
print(df[num_cols + cat_cols].isna().sum())
# Out:
# worth_car       302
# weight_car      302
# mileage_car     302
# power_car       302
# chassis         302
# fuel_car        302
# drive           302
# turbo           302
# transmission    302
# dtype: int64

# %%
mode_income = (
    df
    .groupby('zip4')['INCOME']
    .agg(lambda x: x.mode().iloc[0] if not x.mode().empty else np.nan)
    .rename('mode_income')
)

# 2. Merge the mode back into the original DataFrame
df = df.merge(mode_income, left_on='zip4', right_index=True)

# 3. Impute missing INCOME values using the mode for that zip4
df['INCOME_filled'] = df['INCOME'].fillna(df['mode_income'])

# 4. (Optional) Drop the helper column if you no longer need it
df.drop(columns=['mode_income'], inplace=True)

# %%
# 2. Second imputation: For any remaining NaNs in INCOME, use PROVINCE-level mode
#    - Compute mode income per PROVINCE based on the “INCOME_imputed_zip4” column
mode_income_prov = (
    df
    .groupby('PROVINCE')['INCOME_filled']
    .agg(lambda x: x.mode().iloc[0] if not x.mode().empty else np.nan)
    .rename('mode_income_prov')
)

# Merge and fill any remaining NaNs based on province mode
df = df.merge(mode_income_prov, left_on='PROVINCE', right_index=True)
df['INCOME_final'] = df['INCOME_filled'].fillna(df['mode_income_prov'])

# Drop helper columns if desired
df.drop(columns=["INCOME", 'INCOME_filled', 'mode_income_prov'], inplace=True)

# %% [markdown]
# ## ANALYSIS

# %%
columns_to_keep = ['brand', #funnel
                   'premium_total', 'premium_discount', # from policy tape
                   'worth_car','weight_car', 'mileage_car', 'power_car', 'fuel_car',#'chassis', 'drive', 'turbo', 'transmission',
                   
                   "PROVINCE", 'URB', 'INCOME_final', 'SOCCL_A', 'SOCCL_B1', 'SOCCL_B2', 'SOCCL_C',
                   'SOCCL_D', 'EDU_HIGH', 'EDU_MID', 'EDU_LOW', 'DINK',
                   'OWN_HOUSE', 'AVG_HOUSE',
                   'STAGE_OF_LIFE',# 'SINGLE', 'FAM', 'FAM_WCHILD', 'SINGLES_YOUNG', 'SINGLES_MID', 'SINGLES_OLD', 'FAM_CHILD_Y', 'FAM_CHILD_O', 'FAM_WCHILD_Y', 'FAM_WCHILD_MED','FAM_WCHILD_OLD',
                   'CIT_HOUSEHOLD', 'LOAN', 'SAVINGS', 'SHOP_ONLINE','CAR', # from regional

                   'age', 'coverage_type','car_age', # from new columns                  
       ]

# %%
df_sub = df[(df["affinity_name"]=="T&B")&(df["conv"]==1)][columns_to_keep].copy()

# %%
df_sub.shape
# Out:
# (495, 31)

# %%
print(df_sub.isna().sum())
# Out:
# brand               0
# premium_total       0
# premium_discount    0
# worth_car           6
# weight_car          6
# mileage_car         6
# power_car           6
# fuel_car            6
# PROVINCE            0
# URB                 0
# INCOME_final        0
# SOCCL_A             5
# SOCCL_B1            5
# SOCCL_B2            5
# SOCCL_C             5
# SOCCL_D             5
# EDU_HIGH            5
# EDU_MID             5
# EDU_LOW             5
# DINK                5
# OWN_HOUSE           5
# AVG_HOUSE           8
# STAGE_OF_LIFE       7
# CIT_HOUSEHOLD       5
# LOAN                5
# SAVINGS             5
# SHOP_ONLINE         5
# CAR                 5
# age                 0
# coverage_type       0
# car_age             0
# dtype: int64

# %%
df_sub.dropna(axis=0, how='any', inplace=True)

# %%
print(df_sub.isna().sum())
# Out:
# brand               0
# premium_total       0
# premium_discount    0
# worth_car           0
# weight_car          0
# mileage_car         0
# power_car           0
# fuel_car            0
# PROVINCE            0
# URB                 0
# INCOME_final        0
# SOCCL_A             0
# SOCCL_B1            0
# SOCCL_B2            0
# SOCCL_C             0
# SOCCL_D             0
# EDU_HIGH            0
# EDU_MID             0
# EDU_LOW             0
# DINK                0
# OWN_HOUSE           0
# AVG_HOUSE           0
# STAGE_OF_LIFE       0
# CIT_HOUSEHOLD       0
# LOAN                0
# SAVINGS             0
# SHOP_ONLINE         0
# CAR                 0
# age                 0
# coverage_type       0
# car_age             0
# dtype: int64

# %%
cat_features = ['PROVINCE',
                'coverage_type',
                'fuel_car'] #'chassis', 'drive','turbo','transmission']

# the ones you want to exclude
exclude = ['brand']

columns_to_keep_kmeans = [c for c in columns_to_keep if c not in exclude]

num_features = [col for col in columns_to_keep_kmeans if col not in cat_features]
df_km = df_sub[columns_to_keep_kmeans].copy()

# %%
df_km.columns
# Out:
# Index(['premium_total', 'premium_discount', 'worth_car', 'weight_car',
#        'mileage_car', 'power_car', 'fuel_car', 'PROVINCE', 'URB',
#        'INCOME_final', 'SOCCL_A', 'SOCCL_B1', 'SOCCL_B2', 'SOCCL_C', 'SOCCL_D',
#        'EDU_HIGH', 'EDU_MID', 'EDU_LOW', 'DINK', 'OWN_HOUSE', 'AVG_HOUSE',
#        'STAGE_OF_LIFE', 'CIT_HOUSEHOLD', 'LOAN', 'SAVINGS', 'SHOP_ONLINE',
#        'CAR', 'age', 'coverage_type', 'car_age'],
#       dtype='object')

# %%
num_pipe = Pipeline([
    ('scaler', StandardScaler())
])

cat_pipe = Pipeline([
    ('ohe', OneHotEncoder(handle_unknown='ignore'))
])

preprocessor = ColumnTransformer([
    ('num', num_pipe, num_features),
    ('cat', cat_pipe, cat_features)
])

# %%
# 1️⃣ Fit PCA on the pre-processed data
X_prepared = preprocessor.fit_transform(df_km)
pca = PCA().fit(X_prepared)

# 2️⃣ Plot cumulative explained variance
plt.step(range(1, len(pca.explained_variance_ratio_)+1),
         np.cumsum(pca.explained_variance_ratio_)*100, where='mid')
plt.xlabel("Principal Components")
plt.ylabel("Cumulative % variance explained")
plt.axhline(80, ls='--')
plt.show()

# %%
loadings = pd.DataFrame(
    pca.components_.T,
    index = preprocessor.get_feature_names_out(),
    columns = [f'PC{i+1}' for i in range(pca.n_components_)]
)

# Show top ±5 strongest contributors for the first few PCs
for pc in loadings.columns[:10]:
    print(f"\n=== {pc} ===")
    print(loadings[pc].abs().sort_values(ascending=False).head(10))
# Out:
# === PC1 ===
# num__SHOP_ONLINE    0.289436
# num__DINK           0.285729
# num__OWN_HOUSE      0.280361
# num__SOCCL_A        0.278148
# num__EDU_LOW        0.269746
# num__AVG_HOUSE      0.267791
# num__SOCCL_C        0.265660
# num__SAVINGS        0.261945
# num__EDU_HIGH       0.257940
# num__SOCCL_D        0.255850
# Name: PC1, dtype: float64
#
# === PC2 ===
# num__worth_car            0.521524
# num__weight_car           0.514237
# num__power_car            0.498578
# num__premium_total        0.274139
# num__premium_discount     0.189466
# num__car_age              0.166355
# cat__fuel_car_GASOLINE    0.122824
# cat__fuel_car_DIESEL      0.117521
# num__LOAN                 0.114529
# num__CIT_HOUSEHOLD        0.077630
# Name: PC2, dtype: float64
#
# === PC3 ===
# num__EDU_MID        0.486934
# num__LOAN           0.362312
# num__SOCCL_B2       0.323105
# num__SOCCL_B1       0.277282
# num__SOCCL_A        0.237661
# num__SOCCL_D        0.224766
# num__age            0.223132
# num__SHOP_ONLINE    0.201844
# num__EDU_LOW        0.188869
# num__URB            0.187521
# Name: PC3, dtype: float64
#
# === PC4 ===
# num__URB              0.349826
# num__EDU_HIGH         0.341464
# num__STAGE_OF_LIFE    0.336731
# num__CAR              0.326736
# num__CIT_HOUSEHOLD    0.309621
# num__SOCCL_B2         0.292688
# num__EDU_LOW          0.287155
# num__SOCCL_A          0.260738
# num__SAVINGS          0.198833
# num__INCOME_final     0.187778
# Name: PC4, dtype: float64
#
# === PC5 ===
# num__CIT_HOUSEHOLD       0.430320
# num__EDU_MID             0.338375
# num__premium_discount    0.333538
# num__LOAN                0.331636
# num__age                 0.304757
# num__premium_total       0.271021
# num__URB                 0.215497
# num__power_car           0.207964
# num__SOCCL_B1            0.190701
# num__weight_car          0.176416
# Name: PC5, dtype: float64
#
# === PC6 ===
# num__premium_discount                             0.482502
# num__premium_total                                0.475774
# num__LOAN                                         0.297691
# num__car_age                                      0.268193
# num__SOCCL_B2                                     0.234843
# num__mileage_car                                  0.227918
# num__EDU_MID                                      0.193249
# num__INCOME_final                                 0.162335
# num__SOCCL_B1                                     0.145557
# cat__coverage_type_1. Only liability insurance    0.143467
# Name: PC6, dtype: float64
#
# === PC7 ===
# num__car_age                                      0.570556
# num__age                                          0.465098
# num__URB                                          0.372990
# num__LOAN                                         0.248550
# cat__coverage_type_1. Only liability insurance    0.200030
# num__premium_discount                             0.186723
# num__mileage_car                                  0.165204
# num__SOCCL_B2                                     0.148152
# cat__coverage_type_3. Liability + full casco      0.137445
# cat__PROVINCE_South Holland                       0.133092
# Name: PC7, dtype: float64
#
# === PC8 ===
# num__mileage_car                                   0.840698
# num__car_age                                       0.351888
# num__premium_discount                              0.155674
# cat__coverage_type_1. Only liability insurance     0.137752
# num__CIT_HOUSEHOLD                                 0.136850
# num__URB                                           0.104856
# num__premium_total                                 0.103801
# num__SOCCL_C                                       0.100236
# num__power_car                                     0.096089
# cat__coverage_type_2. Liability + limited casco    0.089673
# Name: PC8, dtype: float64
#
# === PC9 ===
# num__SOCCL_B2            0.505157
# num__INCOME_final        0.475407
# num__CIT_HOUSEHOLD       0.288825
# num__premium_discount    0.278290
# num__URB                 0.243281
# num__SOCCL_D             0.235950
# num__age                 0.225520
# num__DINK                0.205187
# num__SOCCL_B1            0.197758
# num__EDU_MID             0.173140
# Name: PC9, dtype: float64
#
# === PC10 ===
# num__age                 0.537075
# num__car_age             0.328484
# num__INCOME_final        0.300937
# num__SOCCL_B2            0.287089
# num__SOCCL_D             0.259071
# num__URB                 0.249245
# num__mileage_car         0.248318
# num__premium_discount    0.227895
# num__AVG_HOUSE           0.174489
# num__SOCCL_B1            0.160855
# Name: PC10, dtype: float64

# %%
def top_n_loadings(pca, preprocessor, n=5):
    # 1) assemble the full loading matrix
    loadings = pd.DataFrame(
        pca.components_.T,
        index=preprocessor.get_feature_names_out(),
        columns=[f'PC{i+1}' for i in range(pca.n_components_)]
    )

    # 2) for each PC, grab the top-n features by absolute loading
    top_feats = {}
    for pc in loadings.columns:
        top_feats[pc] = (
            loadings[pc]
            .abs()
            .nlargest(n)
            .index
            .tolist()
        )

    # 3) build a DataFrame (rows = rank, cols = PCs)
    return pd.DataFrame(top_feats)

# usage:
top5 = top_n_loadings(pca, preprocessor, n=10)
print(top5)
# Out:
#                 PC1                     PC2               PC3  \
# 0  num__SHOP_ONLINE          num__worth_car      num__EDU_MID
# 1         num__DINK         num__weight_car         num__LOAN
# 2    num__OWN_HOUSE          num__power_car     num__SOCCL_B2
# 3      num__SOCCL_A      num__premium_total     num__SOCCL_B1
# 4      num__EDU_LOW   num__premium_discount      num__SOCCL_A
# 5    num__AVG_HOUSE            num__car_age      num__SOCCL_D
# 6      num__SOCCL_C  cat__fuel_car_GASOLINE          num__age
# 7      num__SAVINGS    cat__fuel_car_DIESEL  num__SHOP_ONLINE
# 8     num__EDU_HIGH               num__LOAN      num__EDU_LOW
# 9      num__SOCCL_D      num__CIT_HOUSEHOLD          num__URB
#
#                   PC4                    PC5  \
# 0            num__URB     num__CIT_HOUSEHOLD
# 1       num__EDU_HIGH           num__EDU_MID
# 2  num__STAGE_OF_LIFE  num__premium_discount
# 3            num__CAR              num__LOAN
# 4  num__CIT_HOUSEHOLD               num__age
# 5       num__SOCCL_B2     num__premium_total
# 6        num__EDU_LOW               num__URB
# 7        num__SOCCL_A         num__power_car
# 8        num__SAVINGS          num__SOCCL_B1
# 9   num__INCOME_final        num__weight_car
#
#                                               PC6  \
# 0                           num__premium_discount
# 1                              num__premium_total
# 2                                       num__LOAN
# 3                                    num__car_age
# 4                                   num__SOCCL_B2
# 5                                num__mileage_car
# 6                                    num__EDU_MID
# 7                               num__INCOME_final
# 8                                   num__SOCCL_B1
# 9  cat__coverage_type_1. Only liability insurance
#
#                                               PC7  \
# 0                                    num__car_age
# 1                                        num__age
# 2                                        num__URB
# 3                                       num__LOAN
# 4  cat__coverage_type_1. Only liability insurance
# 5                           num__premium_discount
# 6                                num__mileage_car
# 7                                   num__SOCCL_B2
# 8    cat__coverage_type_3. Liability + full casco
# 9                     cat__PROVINCE_South Holland
#
#                                                PC8                    PC9  \
# 0                                 num__mileage_car          num__SOCCL_B2
# 1                                     num__car_age      num__INCOME_final
# 2                            num__premium_discount     num__CIT_HOUSEHOLD
# 3   cat__coverage_type_1. Only liability insurance  num__premium_discount
# 4                               num__CIT_HOUSEHOLD               num__URB
# 5                                         num__URB           num__SOCCL_D
# 6                               num__premium_total               num__age
# 7                                     num__SOCCL_C              num__DINK
# 8                                   num__power_car          num__SOCCL_B1
# 9  cat__coverage_type_2. Liability + limited casco           num__EDU_MID
#
#                     PC10  ...                         PC37  \
# 0               num__age  ...        cat__PROVINCE_Limburg
# 1           num__car_age  ...      cat__PROVINCE_Friesland
# 2      num__INCOME_final  ...  cat__PROVINCE_North Brabant
# 3          num__SOCCL_B2  ...      cat__PROVINCE_Flevoland
# 4           num__SOCCL_D  ...        cat__PROVINCE_Utrecht
# 5               num__URB  ...  cat__PROVINCE_North Holland
# 6       num__mileage_car  ...      cat__PROVINCE_Groningen
# 7  num__premium_discount  ...     cat__PROVINCE_Overijssel
# 8         num__AVG_HOUSE  ...  cat__PROVINCE_South Holland
# 9          num__SOCCL_B1  ...     cat__PROVINCE_Gelderland
#
#                           PC38                         PC39  \
# 0      cat__PROVINCE_Friesland      cat__PROVINCE_Flevoland
# 1        cat__PROVINCE_Limburg      cat__PROVINCE_Friesland
# 2      cat__PROVINCE_Flevoland        cat__PROVINCE_Limburg
# 3      cat__PROVINCE_Groningen               num__worth_car
# 4  cat__PROVINCE_North Brabant               num__power_car
# 5     cat__PROVINCE_Gelderland      cat__PROVINCE_Groningen
# 6     cat__PROVINCE_Overijssel  cat__PROVINCE_North Brabant
# 7        cat__PROVINCE_Utrecht                 num__SOCCL_A
# 8  cat__PROVINCE_North Holland                num__EDU_HIGH
# 9  cat__PROVINCE_South Holland     cat__PROVINCE_Overijssel
#
#                           PC40                         PC41  \
# 0        cat__PROVINCE_Drenthe       cat__fuel_car_HYBR/GAS
# 1      cat__PROVINCE_Flevoland       cat__fuel_car_GASOLINE
# 2      cat__PROVINCE_Friesland         cat__fuel_car_DIESEL
# 3        cat__PROVINCE_Limburg            cat__fuel_car_LPG
# 4      cat__PROVINCE_Groningen        cat__PROVINCE_Zeeland
# 5  cat__PROVINCE_North Holland               num__power_car
# 6  cat__PROVINCE_North Brabant              num__weight_car
# 7        cat__PROVINCE_Utrecht  cat__PROVINCE_North Brabant
# 8     cat__PROVINCE_Gelderland               num__worth_car
# 9     cat__PROVINCE_Overijssel                 num__SOCCL_A
#
#                           PC42                     PC43  \
# 0        cat__PROVINCE_Zeeland        cat__fuel_car_LPG
# 1        cat__PROVINCE_Drenthe   cat__fuel_car_HYBR/GAS
# 2      cat__PROVINCE_Flevoland     cat__fuel_car_DIESEL
# 3        cat__PROVINCE_Limburg   cat__fuel_car_GASOLINE
# 4      cat__PROVINCE_Groningen    cat__PROVINCE_Zeeland
# 5     cat__PROVINCE_Overijssel           num__power_car
# 6        cat__PROVINCE_Utrecht          num__weight_car
# 7     cat__PROVINCE_Gelderland  cat__PROVINCE_Groningen
# 8  cat__PROVINCE_North Brabant             num__SOCCL_D
# 9  cat__PROVINCE_South Holland  cat__PROVINCE_Friesland
#
#                                               PC44  \
# 0  cat__coverage_type_2. Liability + limited casco
# 1     cat__coverage_type_3. Liability + full casco
# 2   cat__coverage_type_1. Only liability insurance
# 3                           cat__fuel_car_HYBR/GAS
# 4                             cat__fuel_car_DIESEL
# 5                           cat__fuel_car_GASOLINE
# 6                                cat__fuel_car_LPG
# 7                          cat__PROVINCE_Groningen
# 8                      cat__PROVINCE_North Brabant
# 9                            cat__PROVINCE_Utrecht
#
#                                               PC45  \
# 0                                cat__fuel_car_LPG
# 1                           cat__fuel_car_HYBR/GAS
# 2                             cat__fuel_car_DIESEL
# 3                           cat__fuel_car_GASOLINE
# 4     cat__coverage_type_3. Liability + full casco
# 5  cat__coverage_type_2. Liability + limited casco
# 6   cat__coverage_type_1. Only liability insurance
# 7                            cat__PROVINCE_Zeeland
# 8                            cat__PROVINCE_Drenthe
# 9                            cat__PROVINCE_Utrecht
#
#                           PC46
# 0        cat__PROVINCE_Drenthe
# 1        cat__PROVINCE_Limburg
# 2      cat__PROVINCE_Flevoland
# 3  cat__PROVINCE_South Holland
# 4     cat__PROVINCE_Overijssel
# 5     cat__PROVINCE_Gelderland
# 6  cat__PROVINCE_North Brabant
# 7        cat__PROVINCE_Utrecht
# 8      cat__PROVINCE_Friesland
# 9      cat__PROVINCE_Groningen
#
# [10 rows x 46 columns]

# %%
loadings = pd.DataFrame(
    pca.components_.T,
    index=preprocessor.get_feature_names_out(),
    columns=[f'PC{i+1}' for i in range(pca.n_components_)]
)

loadings = loadings.reset_index().rename(columns={'index':'feature'})

# %%
loadings.head(50)
# Out:
#                                             feature       PC1       PC2  \
# 0                                num__premium_total -0.038892  0.274139
# 1                             num__premium_discount -0.042210  0.189466
# 2                                    num__worth_car  0.035155  0.521524
# 3                                   num__weight_car  0.029410  0.514237
# 4                                  num__mileage_car  0.027466  0.066210
# 5                                    num__power_car  0.042644  0.498578
# 6                                          num__URB  0.099716 -0.059673
# 7                                 num__INCOME_final -0.192665  0.005985
# 8                                      num__SOCCL_A  0.278148 -0.020430
# 9                                     num__SOCCL_B1  0.221922 -0.017663
# 10                                    num__SOCCL_B2 -0.114898  0.038063
# 11                                     num__SOCCL_C -0.265660 -0.006952
# 12                                     num__SOCCL_D -0.255850  0.024189
# 13                                    num__EDU_HIGH  0.257940 -0.006756
# 14                                     num__EDU_MID  0.072442 -0.071284
# 15                                     num__EDU_LOW -0.269746  0.042469
# 16                                        num__DINK  0.285729  0.028584
# 17                                   num__OWN_HOUSE  0.280361 -0.024650
# 18                                   num__AVG_HOUSE  0.267791 -0.010827
# 19                               num__STAGE_OF_LIFE  0.185482 -0.010094
# 20                               num__CIT_HOUSEHOLD  0.140680  0.077630
# 21                                        num__LOAN -0.034053  0.114529
# 22                                     num__SAVINGS  0.261945 -0.045206
# 23                                 num__SHOP_ONLINE  0.289436 -0.002088
# 24                                         num__CAR  0.252857 -0.000210
# 25                                         num__age  0.081434 -0.031197
# 26                                     num__car_age -0.089946 -0.166355
# 27                            cat__PROVINCE_Drenthe -0.000467  0.000354
# 28                          cat__PROVINCE_Flevoland  0.001690 -0.001671
# 29                          cat__PROVINCE_Friesland  0.000583 -0.000934
# 30                         cat__PROVINCE_Gelderland  0.015929 -0.014584
# 31                          cat__PROVINCE_Groningen -0.004570 -0.003410
# 32                            cat__PROVINCE_Limburg -0.002043 -0.002113
# 33                      cat__PROVINCE_North Brabant  0.006411  0.004277
# 34                      cat__PROVINCE_North Holland  0.009575 -0.006962
# 35                         cat__PROVINCE_Overijssel  0.002369  0.002966
# 36                      cat__PROVINCE_South Holland -0.025415  0.010275
# 37                            cat__PROVINCE_Utrecht -0.005091  0.014464
# 38                            cat__PROVINCE_Zeeland  0.001030 -0.002661
# 39   cat__coverage_type_1. Only liability insurance -0.053757 -0.058805
# 40  cat__coverage_type_2. Liability + limited casco  0.008253  0.030263
# 41     cat__coverage_type_3. Liability + full casco  0.045505  0.028541
# 42                             cat__fuel_car_DIESEL -0.006086  0.117521
# 43                           cat__fuel_car_GASOLINE  0.007579 -0.122824
# 44                           cat__fuel_car_HYBR/GAS -0.000312  0.004780
# 45                                cat__fuel_car_LPG -0.001181  0.000523
#
#          PC3       PC4       PC5           PC6       PC7       PC8       PC9  \
# 0   0.176654 -0.053004  0.271021  4.757739e-01  0.116686 -0.103801  0.086401
# 1   0.105573 -0.079372  0.333538  4.825021e-01  0.186723  0.155674  0.278290
# 2  -0.044846  0.002588 -0.165730 -1.323853e-01  0.048551 -0.042887 -0.020126
# 3  -0.042530  0.001483 -0.176416 -1.123727e-01  0.052597 -0.071185 -0.029648
# 4  -0.051798  0.048628  0.083704 -2.279185e-01  0.165204  0.840698 -0.114469
# 5  -0.049797  0.000162 -0.207964 -1.305009e-01  0.090958 -0.096089  0.010121
# 6  -0.187521  0.349826 -0.215497  8.747347e-02  0.372990  0.104856  0.243281
# 7  -0.063670  0.187778 -0.047777  1.623347e-01 -0.027405 -0.019590 -0.475407
# 8  -0.237661 -0.260738  0.106220 -1.963584e-02  0.006403 -0.007385  0.019785
# 9   0.277282  0.179947 -0.190701  1.455574e-01 -0.012279 -0.057396 -0.197758
# 10  0.323105  0.292688  0.041166 -2.348427e-01 -0.148152  0.061758  0.505157
# 11 -0.013408 -0.062960 -0.035898 -5.126804e-02  0.030670  0.100236 -0.112450
# 12 -0.224766  0.029058  0.005903  1.297158e-01  0.125938 -0.061588 -0.235950
# 13 -0.178241 -0.341464  0.095816 -8.280702e-02  0.038947 -0.027400  0.081682
# 14  0.486934  0.123573 -0.338375  1.932490e-01  0.042886  0.080790 -0.173140
# 15 -0.188869  0.287155  0.121865 -8.806808e-02 -0.037013 -0.031729  0.064875
# 16  0.067148  0.161080  0.171196 -6.989696e-02  0.020386 -0.061542 -0.205187
# 17 -0.039115  0.158348  0.013488  8.119815e-02  0.122265  0.018234  0.005636
# 18 -0.138848 -0.012565  0.084812  3.037314e-02 -0.033217 -0.049831  0.001373
# 19 -0.164070  0.336731  0.102925  1.126678e-01 -0.056693 -0.055312  0.072820
# 20 -0.070327  0.309621  0.430320 -1.295052e-01 -0.069984 -0.136850 -0.288825
# 21  0.362312 -0.034945  0.331636 -2.976909e-01 -0.248550 -0.054874 -0.022581
# 22  0.137486 -0.198833 -0.138442  3.813602e-03  0.099516  0.029485 -0.026186
# 23  0.201844 -0.085212  0.005663 -1.016766e-01  0.011094  0.028294 -0.081254
# 24 -0.068150  0.326736  0.071395 -3.186276e-02  0.052562 -0.006709  0.081079
# 25 -0.223132  0.075688 -0.304757  1.028943e-01 -0.465098 -0.064753  0.225520
# 26  0.091475  0.003179  0.013563 -2.681925e-01  0.570556 -0.351888  0.076863
# 27 -0.001225  0.002788 -0.003212  5.949112e-07 -0.002916  0.004121  0.005604
# 28  0.006484 -0.006876  0.002480 -7.381783e-03 -0.002594 -0.001196  0.011775
# 29 -0.009989  0.010719 -0.004487  1.851766e-03  0.012771  0.004923 -0.000404
# 30  0.005666  0.008421 -0.006328  8.030325e-04  0.047107  0.043334  0.018647
# 31 -0.011932  0.014649 -0.022530  7.089765e-03  0.030467 -0.010748  0.003337
# 32  0.002955  0.005111 -0.009066 -3.445324e-03  0.008590  0.010874  0.011283
# 33 -0.006628  0.007567 -0.018400  3.558229e-03 -0.000111 -0.002274  0.016125
# 34  0.007146 -0.038687  0.003009 -1.714719e-02 -0.004024 -0.037041  0.024717
# 35 -0.009099  0.035544 -0.000803 -9.092387e-03  0.025600 -0.010166 -0.018059
# 36  0.009590 -0.009610  0.029750  2.133019e-02 -0.133092 -0.050044 -0.016736
# 37  0.010175 -0.027866  0.029979  1.232895e-03  0.018193  0.043145 -0.055877
# 38 -0.003143 -0.001761 -0.000392  1.200216e-03  0.000010  0.005072 -0.000412
# 39  0.048567 -0.016460  0.018558 -1.434670e-01  0.200030 -0.137752  0.012624
# 40 -0.017132 -0.000409  0.034667  5.845893e-02 -0.062585  0.089673  0.011476
# 41 -0.031435  0.016869 -0.053226  8.500803e-02 -0.137445  0.048079 -0.024100
# 42  0.024300 -0.003522  0.025061  3.234159e-02 -0.024279  0.038921 -0.042342
# 43 -0.024484  0.005258 -0.030391 -4.333781e-02  0.027594 -0.037141  0.040292
# 44  0.000175 -0.000117  0.001328  7.878681e-03 -0.002017 -0.004519  0.000816
# 45  0.000009 -0.001619  0.004002  3.117534e-03 -0.001299  0.002739  0.001235
#
#     ...      PC37      PC38      PC39      PC40      PC41      PC42      PC43  \
# 0   ... -0.008414 -0.015246  0.007335 -0.003836 -0.011140 -0.001716  0.009288
# 1   ...  0.008978  0.010344 -0.009016  0.002657 -0.007704  0.003029 -0.012179
# 2   ...  0.025568 -0.009780  0.097377  0.007542 -0.022647 -0.004151  0.010485
# 3   ... -0.022964  0.011325 -0.013135  0.003238 -0.041629  0.023709  0.017059
# 4   ... -0.020482 -0.007572  0.001977  0.000231  0.003297 -0.005728 -0.000907
# 5   ... -0.004047  0.006859 -0.073112 -0.008159  0.057610 -0.012254 -0.021581
# 6   ... -0.025660 -0.003083  0.017101 -0.003400 -0.009051 -0.005718  0.002814
# 7   ... -0.013268 -0.004825 -0.002478 -0.004753 -0.001853 -0.008997 -0.001366
# 8   ... -0.018058  0.000350  0.054259 -0.018191  0.020539 -0.018183 -0.007052
# 9   ... -0.020334 -0.006343  0.014862  0.009031  0.010161  0.000137 -0.003683
# 10  ... -0.021878 -0.001549  0.021294 -0.004781  0.012744 -0.001379  0.004160
# 11  ...  0.005774  0.003034  0.024521 -0.000255  0.007587  0.006851 -0.001814
# 12  ...  0.023929 -0.005707  0.026372  0.005116 -0.003189  0.008673  0.013788
# 13  ... -0.009174 -0.005308 -0.053136  0.016628  0.013087  0.019010  0.003110
# 14  ...  0.018955  0.009049 -0.007404  0.000700  0.011990  0.011385  0.002938
# 15  ...  0.029590 -0.018204 -0.028532 -0.007797  0.014166  0.005154 -0.006332
# 16  ... -0.027879  0.001964  0.032269  0.004062  0.004106 -0.026242 -0.000705
# 17  ...  0.012417 -0.014644 -0.009648 -0.002844 -0.013585  0.007887  0.006356
# 18  ...  0.051741 -0.011766  0.003763  0.011967 -0.011872 -0.005868  0.009627
# 19  ... -0.020758 -0.007519  0.003334  0.002802  0.002602 -0.000625  0.001751
# 20  ...  0.015590  0.006025  0.005329 -0.000416  0.002596  0.017627 -0.003279
# 21  ...  0.001150  0.003374 -0.022872  0.003006 -0.015858  0.001293  0.003481
# 22  ...  0.002302 -0.000213  0.008610 -0.010072 -0.006361  0.005938 -0.001757
# 23  ...  0.047217 -0.014432 -0.028510 -0.007819  0.000700  0.005087  0.002119
# 24  ...  0.013352  0.014846 -0.012569 -0.003837  0.006356  0.014979 -0.001735
# 25  ...  0.000811 -0.007516 -0.005936 -0.006256 -0.006781  0.001326  0.001350
# 26  ... -0.006553  0.009123  0.006953  0.011920  0.000792  0.001446  0.009355
# 27  ...  0.056698  0.039408  0.038307  0.942186 -0.011804 -0.143216  0.003706
# 28  ...  0.225898  0.312212  0.839468 -0.167922 -0.014038 -0.104439  0.007673
# 29  ...  0.316707  0.741554 -0.483547 -0.129582 -0.003152 -0.071056 -0.013488
# 30  ... -0.152830 -0.073774 -0.037723 -0.079687  0.003157 -0.077714 -0.006955
# 31  ... -0.211049 -0.097503 -0.071246 -0.092347  0.011699 -0.087838 -0.014848
# 32  ...  0.748319 -0.550996 -0.128242 -0.119123 -0.015087 -0.088249 -0.004331
# 33  ... -0.243087 -0.095781 -0.060588 -0.085262 -0.041074 -0.077611  0.005195
# 34  ... -0.213040 -0.067564 -0.018920 -0.088912  0.004871 -0.068562 -0.006440
# 35  ... -0.167093 -0.072666 -0.043816 -0.078215 -0.006302 -0.078456 -0.002231
# 36  ... -0.159097 -0.065148 -0.024225 -0.072190 -0.015760 -0.073903 -0.000592
# 37  ... -0.215601 -0.068668 -0.038062 -0.083476 -0.001280 -0.078091  0.002532
# 38  ...  0.014174 -0.001073  0.028594  0.054530  0.088770  0.949134  0.029779
# 39  ...  0.003652 -0.035354 -0.011800 -0.008903  0.004546 -0.003214 -0.012971
# 40  ... -0.004105  0.023944  0.012505  0.002258 -0.002411  0.007423  0.006701
# 41  ...  0.000453  0.011410 -0.000705  0.006645 -0.002135 -0.004209  0.006270
# 42  ...  0.015207 -0.010609 -0.019522 -0.002614 -0.449607  0.044768 -0.169291
# 43  ... -0.020392  0.014070  0.015988  0.006039 -0.488645  0.051868 -0.151055
# 44  ...  0.003251 -0.004608  0.016558  0.004283  0.693222 -0.048199 -0.508313
# 45  ...  0.001933  0.001147 -0.013023 -0.007708  0.245029 -0.048438  0.828659
#
#             PC44          PC45          PC46
# 0   0.000000e+00  0.000000e+00  0.000000e+00
# 1   4.192194e-17 -3.996849e-15  9.433064e-17
# 2  -5.064368e-16 -4.146634e-16 -4.556730e-17
# 3   1.795944e-15  7.635499e-16  2.689520e-16
# 4  -1.905748e-16 -3.639912e-16 -1.115051e-16
# 5  -8.288055e-16  8.393235e-16 -1.614727e-16
# 6  -2.089414e-16 -8.693699e-16 -5.161923e-17
# 7   1.541675e-16 -6.816173e-16 -1.439589e-17
# 8   5.800037e-16  3.573516e-15 -3.422075e-16
# 9  -6.830006e-16  4.852905e-16 -2.300791e-16
# 10 -3.363741e-16  2.959539e-15 -1.574025e-16
# 11 -5.981086e-16  2.663226e-16 -1.201773e-16
# 12  1.903978e-16  4.035327e-15  2.739041e-17
# 13  7.883540e-16  2.340400e-15  3.014488e-16
# 14  1.650485e-15  3.808254e-15  2.587423e-16
# 15  1.798882e-15  2.124403e-15  3.759019e-16
# 16 -6.585072e-16 -1.089512e-15 -1.092529e-17
# 17  1.230393e-16 -2.292581e-17  1.915849e-16
# 18  2.499931e-17  3.697433e-16  3.297868e-16
# 19 -1.070177e-16  7.757022e-16  1.666743e-18
# 20  7.314844e-17 -1.396232e-16 -3.035260e-17
# 21  2.521424e-16 -7.469890e-16  5.717122e-17
# 22  8.707281e-17 -3.804704e-16  6.640479e-17
# 23  3.305291e-16  2.027285e-16  7.347696e-17
# 24  4.136961e-16  1.503206e-15 -1.623382e-16
# 25  6.089237e-17 -7.388531e-16 -2.641038e-17
# 26  9.423611e-17  2.874352e-15  5.242056e-17
# 27 -7.780203e-02  1.202846e-01  2.506228e-01
# 28 -7.780203e-02  1.202846e-01  2.506228e-01
# 29 -7.780203e-02  1.202846e-01  2.506228e-01
# 30 -7.780203e-02  1.202846e-01  2.506228e-01
# 31 -7.780203e-02  1.202846e-01  2.506228e-01
# 32 -7.780203e-02  1.202846e-01  2.506228e-01
# 33 -7.780203e-02  1.202846e-01  2.506228e-01
# 34 -7.780203e-02  1.202846e-01  2.506228e-01
# 35 -7.780203e-02  1.202846e-01  2.506228e-01
# 36 -7.780203e-02  1.202846e-01  2.506228e-01
# 37 -7.780203e-02  1.202846e-01  2.506228e-01
# 38 -7.780203e-02  1.202846e-01  2.506228e-01
# 39  4.978136e-01  2.920766e-01  1.435864e-02
# 40  4.978136e-01  2.920766e-01  1.435864e-02
# 41  4.978136e-01  2.920766e-01  1.435864e-02
# 42 -2.144218e-01  3.776418e-01 -2.478103e-01
# 43 -2.144218e-01  3.776418e-01 -2.478103e-01
# 44 -2.144218e-01  3.776418e-01 -2.478103e-01
# 45 -2.144218e-01  3.776418e-01 -2.478103e-01
#
# [46 rows x 47 columns]

# %%
wcss = []                         # within-cluster sum of squares
K = range(2, 15)
for k in K:
    km = KMeans(n_clusters=k, random_state=42)
    km.fit(X_prepared)
    wcss.append(km.inertia_)

plt.plot(K, wcss, marker='o')
plt.xlabel('k')
plt.ylabel('WCSS')
plt.title('Elbow Method')
plt.show()

# %%
sil = []
for k in K:
    km = KMeans(n_clusters=k, random_state=42)
    labels = km.fit_predict(X_prepared)
    sil.append(silhouette_score(X_prepared, labels))

plt.plot(K, sil, marker='o')
plt.xlabel('k')
plt.ylabel('Average silhouette')
plt.title('Silhouette Analysis')
plt.show()

# %%
k_final = 8
n_pcs   = 12            # or whatever your elbow-cum-variance plot suggested

pipeline = Pipeline([
    ('prep', preprocessor),
    ('pca',  PCA(n_components=n_pcs, random_state=42)),   # comment out if you skip PCA
    ('km',   KMeans(n_clusters=k_final, random_state=42))
])

df_km['cluster'] = pipeline.fit_predict(df_km)

# %%
sizes = df_km['cluster'].value_counts().sort_index()
print(sizes)
# Out:
# cluster
# 0    68
# 1    62
# 2    58
# 3    69
# 4    63
# 5    52
# 6    39
# 7    70
# Name: count, dtype: int64

# %%
centroids_pca = pipeline.named_steps['km'].cluster_centers_
centroids_pca = pd.DataFrame(centroids_pca,
                             columns=[f'PC{i+1}' for i in range(centroids_pca.shape[1])])

# %%
pcs = pipeline.named_steps['pca'].transform(preprocessor.transform(df_km))
sns.scatterplot(x=pcs[:,0], 
                y=pcs[:,1], 
                hue=df_km['cluster'], 
                size=pcs[:,8],
                palette='tab10', 
                alpha=.5)
plt.xlabel('PC1'); plt.ylabel('PC2')
plt.title('Cluster separation in PCA space')
plt.show()

# %%
df_km
# Out:
#       premium_total  premium_discount     worth_car   weight_car  mileage_car  \
# 952          757.47              7.49  10630.000000   839.000000    15.000000
# 1109         961.36              0.00  17134.000000   954.000000    15.000000
# 1120        1923.90             45.92  26990.000000  1225.000000    15.000000
# 1220        1121.39              7.49  36486.000000  1405.000000    20.000000
# 1237         817.26              0.00  17695.000000  1076.000000    15.000000
# ...             ...               ...           ...          ...          ...
# 9194           0.00              0.00  11864.000000   830.800000    13.000000
# 9195           0.00              0.00  16098.809524  1014.904762    14.761905
# 9199           0.00              0.00  16098.809524  1014.904762    14.761905
# 9205           0.00              0.00  15378.481481   955.962963    13.518519
# 9222           0.00              0.00  15728.500000   985.500000    15.000000
#
#       power_car  fuel_car       PROVINCE  URB  INCOME_final  ...  \
# 952   55.000000  GASOLINE  North Brabant  7.0           2.0  ...
# 1109  44.000000  GASOLINE  North Brabant  2.0           2.0  ...
# 1120  86.000000  GASOLINE  South Holland  4.0           2.0  ...
# 1220  92.000000    DIESEL        Utrecht  2.0           2.0  ...
# 1237  55.000000  GASOLINE      Groningen  2.0           4.0  ...
# ...         ...       ...            ...  ...           ...  ...
# 9194  53.800000  GASOLINE  South Holland  1.0           4.0  ...
# 9195  58.333333  GASOLINE  South Holland  1.0           4.0  ...
# 9199  58.333333  GASOLINE        Utrecht  4.0           2.0  ...
# 9205  62.370370  GASOLINE     Overijssel  4.0           2.0  ...
# 9222  53.750000  GASOLINE     Gelderland  7.0           3.0  ...
#
#       STAGE_OF_LIFE  CIT_HOUSEHOLD  LOAN  SAVINGS  SHOP_ONLINE  CAR   age  \
# 952             4.0            5.0   1.0      4.0          6.0  5.0  53.0
# 1109            9.0            5.0   2.0      6.0          6.0  5.0  63.0
# 1120            9.0            3.0   1.0      5.0          4.0  5.0  72.0
# 1220            6.0            5.0   4.0      5.0          6.0  5.0  66.0
# 1237            6.0            4.0   3.0      2.0          2.0  2.0  41.0
# ...             ...            ...   ...      ...          ...  ...   ...
# 9194            4.0            5.0   6.0      6.0          6.0  5.0  54.0
# 9195            1.0            4.0   4.0      2.0          1.0  1.0  61.0
# 9199            6.0            4.0   4.0      4.0          4.0  4.0  24.0
# 9205            6.0            6.0   2.0      6.0          6.0  5.0  21.0
# 9222            6.0            4.0   3.0      4.0          4.0  5.0  34.0
#
#                      coverage_type  car_age  cluster
# 952   2. Liability + limited casco      8.0        7
# 1109  2. Liability + limited casco     10.0        1
# 1120     3. Liability + full casco      8.0        7
# 1220   1. Only liability insurance     16.0        6
# 1237   1. Only liability insurance     18.0        0
# ...                            ...      ...      ...
# 9194   1. Only liability insurance     11.0        4
# 9195     3. Liability + full casco      7.0        0
# 9199   1. Only liability insurance      6.0        4
# 9205   1. Only liability insurance     17.0        4
# 9222   1. Only liability insurance     18.0        7
#
# [481 rows x 31 columns]

# %%
df_km.to_csv("customers_with_clusters.csv", index=False)

# %%
# 1. grab fitted steps
scaler = pipeline.named_steps['prep'] \
                .named_transformers_['num'] \
                .named_steps['scaler']
ohe    = pipeline.named_steps['prep'] \
                .named_transformers_['cat'] \
                .named_steps['ohe']
pca    = pipeline.named_steps['pca']
km     = pipeline.named_steps['km']

# 2. get cluster centers in PCA space
centroids_pca = km.cluster_centers_

# 3. inverse‐PCA → back to scaled & one-hot space
centroids_preproc = pca.inverse_transform(centroids_pca)

# 4. split numeric vs encoded parts
n_num = len(num_features)
num_scaled = centroids_preproc[:, :n_num]
cat_encoded = centroids_preproc[:, n_num:]

# 5. inverse‐scale numerics → original units
num_orig = scaler.inverse_transform(num_scaled)

# 6. inverse‐encode categoricals → original PROVINCE values
#    Note: result is shape (n_clusters, 1)
province_orig = ohe.inverse_transform(cat_encoded).ravel()

# 7. assemble into a DataFrame
centroids_df = pd.DataFrame(num_orig, columns=num_features)
centroids_df['PROVINCE'] = province_orig

# 8. round for readability
centroids_df[num_features] = centroids_df[num_features].round(2)

print("Cluster centers back in original feature space:")
print(centroids_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[130], line 31
#      29 # 7. assemble into a DataFrame
#      30 centroids_df = pd.DataFrame(num_orig, columns=num_features)
# ---> 31 centroids_df['PROVINCE'] = province_orig
#      33 # 8. round for readability
#      34 centroids_df[num_features] = centroids_df[num_features].round(2)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4316, in DataFrame.__setitem__(self, key, value)
#    4313     self._setitem_array([key], value)
#    4314 else:
#    4315     # set column
# -> 4316     self._set_item(key, value)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4529, in DataFrame._set_item(self, key, value)
#    4519 def _set_item(self, key, value) -> None:
#    4520     """
#    4521     Add series to DataFrame in specified column.
#    4522
#    (...)   4527     ensure homogeneity.
#    4528     """
# -> 4529     value, refs = self._sanitize_column(value)
#    4531     if (
#    4532         key in self.columns
#    4533         and value.ndim == 1
#    4534         and not isinstance(value.dtype, ExtensionDtype)
#    4535     ):
#    4536         # broadcast across multiple columns if necessary
#    4537         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:5273, in DataFrame._sanitize_column(self, value)
#    5270     return _reindex_for_setitem(value, self.index)
#    5272 if is_list_like(value):
# -> 5273     com.require_length_match(value, self.index)
#    5274 arr = sanitize_array(value, self.index, copy=True, allow_2d=True)
#    5275 if (
#    5276     isinstance(value, Index)
#    5277     and value.dtype == "object"
#    (...)   5280     # TODO: Remove kludge in sanitize_array for string mode when enforcing
#    5281     # this deprecation
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\common.py:573, in require_length_match(data, index)
#     569 """
#     570 Check the length of data matches the length of the index.
#     571 """
#     572 if len(data) != len(index):
# --> 573     raise ValueError(
#     574         "Length of values "
#     575         f"({len(data)}) "
#     576         "does not match length of index "
#     577         f"({len(index)})"
#     578     )
#
# ValueError: Length of values (24) does not match length of index (8)

# %%
centroids_df
# Out:
#    premium_total  premium_discount     worth_car   weight_car  mileage_car  \
# 0     568.104646         22.483331  16497.216684   987.706390    14.063550
# 1    1161.521672         29.940539  46530.855629  1477.795166    14.915939
# 2     878.995316         29.453462  24700.318682  1111.325459    15.089249
# 3     414.341118         18.159831  18155.700837   999.962944    14.647243
# 4     620.708575         17.928999  16970.318005   987.744942    14.374493
# 5     483.789261         11.505701  15666.653044   964.529787    14.721851
#
#     power_car       URB  INCOME_final   SOCCL_A  SOCCL_B1  ...  OWN_HOUSE  \
# 0   60.060866  3.148298      4.153783  1.094459  1.170579  ...   1.409891
# 1  120.394793  3.772194      2.615133  2.652801  3.009701  ...   3.605412
# 2   73.149320  2.746810      3.866837  1.025023  1.499612  ...   1.778914
# 3   63.532499  3.291938      1.756055  4.350698  2.220175  ...   3.991765
# 4   60.977225  2.377380      3.038677  1.390947  2.339085  ...   1.953605
# 5   58.256079  4.257273      3.058096  2.224889  3.316588  ...   3.864900
#
#    AVG_HOUSE  STAGE_OF_LIFE  CIT_HOUSEHOLD      LOAN   SAVINGS  SHOP_ONLINE  \
# 0   3.663325       2.793922       3.300356  2.750211  2.700904     1.897648
# 1   7.773116       5.108932       4.339648  3.501770  5.217009     5.608006
# 2   4.768303       4.284723       4.388053  4.021970  2.775428     2.803869
# 3   9.594784       5.806765       4.478902  3.005206  5.606324     5.766275
# 4   4.695652       2.309637       2.779302  3.630020  4.597463     4.229589
# 5   7.503087       6.208209       4.413683  3.043436  4.954925     5.256390
#
#         CAR        age    car_age
# 0  2.046729  35.571677  15.350021
# 1  4.343298  37.494417   9.928958
# 2  2.987378  31.208449  11.034140
# 3  4.435285  40.631151  10.593367
# 4  2.258862  31.748150  13.964470
# 5  4.633871  39.916851  11.399283
#
# [6 rows x 27 columns]

# %%
import pandas as pd

# 1. grab fitted steps
scaler = pipeline.named_steps['prep'] \
                .named_transformers_['num'] \
                .named_steps['scaler']
ohe    = pipeline.named_steps['prep'] \
                .named_transformers_['cat'] \
                .named_steps['ohe']
pca    = pipeline.named_steps['pca']
km     = pipeline.named_steps['km']

# 2. get cluster centers in PCA space
centroids_pca = km.cluster_centers_

# 3. inverse‐PCA → back to scaled & one-hot space
centroids_preproc = pca.inverse_transform(centroids_pca)

# 4. split numeric vs encoded parts
n_num = len(num_features)
num_scaled   = centroids_preproc[:, :n_num]
cat_encoded  = centroids_preproc[:, n_num:]   # shape: (n_clusters, sum_ohe_dims)

# 5. inverse‐scale numerics → original units
num_orig = scaler.inverse_transform(num_scaled)

# 6. inverse‐encode categoricals → back to each original categorical column
#    This returns shape (n_clusters, n_cat_features)
cat_orig = ohe.inverse_transform(cat_encoded)

# 7. assemble into a DataFrame
centroids_df = pd.DataFrame(num_orig, columns=num_features)
centroids_cats = pd.DataFrame(cat_orig, columns=cat_features)
centroids_df = pd.concat([centroids_df, centroids_cats], axis=1)

# 8. round numeric cols for readability
centroids_df[num_features] = centroids_df[num_features].round(2)

print("Cluster centers back in original feature space:")
print(centroids_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[98], line 25
#      22 cat_encoded  = centroids_preproc[:, n_num:]   # shape: (n_clusters, sum_ohe_dims)
#      24 # 5. inverse‐scale numerics → original units
# ---> 25 num_orig = scaler.inverse_transform(num_scaled)
#      27 # 6. inverse‐encode categoricals → back to each original categorical column
#      28 #    This returns shape (n_clusters, n_cat_features)
#      29 cat_orig = ohe.inverse_transform(cat_encoded)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:1139, in StandardScaler.inverse_transform(self, X, copy)
#    1137 else:
#    1138     if self.with_std:
# -> 1139         X *= self.scale_
#    1140     if self.with_mean:
#    1141         X += self.mean_
#
# ValueError: operands could not be broadcast together with shapes (6,4) (27,) (6,4)
